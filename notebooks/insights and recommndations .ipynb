# %% [markdown]
# Task 4: Insights and Recommendations

# %% [markdown]
# 3-Bank Comparison: CBE vs BOA vs Dashen Bank

# %% [markdown]
# 1. Overall Sentiment Comparison
# B| Bank                                  | Mean Polarity | Interpretation                                       |
# | ------------------------------------- | ------------- | ---------------------------------------------------- |
# | **Commercial Bank of Ethiopia (CBE)** | **0.2296**    | Strongest positivity, best customer satisfaction     |
# | **Dashen Bank**                       | **0.2303**    | Slightly higher than CBE — the most positive overall |
# | **Bank of Abyssinia (BOA)**           | **0.1027**    | Lowest sentiment; mixed-to-negative experience       |
#
# 👉 Dashen Bank now comes out #1 in sentiment — but only slightly stronger than CBE.
# 👉 BOA is significantly behind both.
#
# 2. Review Volume & Engagement
# | Bank       | Total Reviews | Notes                        |
# | ---------- | ------------- | ---------------------------- |
# | **CBE**    | 296           | Highest, broad customer base |
# | **BOA**    | 286           | High engagement              |
# | **Dashen** | 286           | Same volume as BOA           |
#
#
# 👉 All three banks have comparable review counts, so comparison is fair.
#
# 3. Sentiment Breakdown
# CBE
#
# Positive: 146
# Negative: 27
# Neutral: 123
#
# → Excellent positive-to-negative ratio (≈ 5:1)
#
# Dashen Bank
#
# Positive: 171
# Negative: 44
# Neutral: 71
# → High positivity, but more negativity than CBE
#
# BOA
#
# Positive: 121
# Negative: 63
# Neutral: 102
#
# → Weak sentiment distribution
#
# 👉 Order of customer happiness → Dashen ≈ CBE >>> BOA
#
# 4. Thematic Comparison (Pain Points & Strengths)
#
# Shared Themes Across Banks
# From your theme counts:
#
# | Theme                   | Count |
# | ----------------------- | ----- |
# | Transaction Performance | 107   |
# | Feature Requests        | 65    |
# | Customer Support        | 51    |
# | UI/UX                   | 49    |
# | Account Access Issues   | 47    |
#
# 📌 Bank of Abyssinia (BOA) – Summary
#
# Pain Points
#
# 1 Frequent transaction failures
# 2 Account access issues (login, OTP)
# 3 App crashes/bugs
# 4 Poor customer support responsiveness
#
# Strengths
#
# 1 Clean, simple UI
# 2 Good account overview features
#
# 👉 Main weakness: stability + support
#
# 📌 Commercial Bank of Ethiopia (CBE) – Summary
#
# Pain Points
#
# 1 UI feels outdated
# 2 Many users ask for new features
# 3 Mid-level neutral feedback (average experience)
#
# Strengths
#
# 1 Reliable transactions
# 2 High stability
# 3 Smooth core banking functions
#
# 👉 Main strength: dependability
#
# 📌 Dashen Bank – Summary
#
# Pain Points
#
# 1 Some transaction delays
# 2 Occasional technical issues
# 3 Users want more convenience features
#
# Strengths
#
# 1 Highest positive sentiment overall
# 2 Smooth and intuitive interface
# 3 Appreciated for functionality & ease of use
#
# 👉 Dashen = balance of usability + functionality
#
# 5. Key Drivers & Pain Points per Bank
# 🔵 Commercial Bank of Ethiopia (CBE)
# What users like:
#
# 1 Reliable transactions
# 2 Stable performance
# 3 Practical daily banking features
#
# Pain points:
#
# 1 Outdated interface
# 2 Users want more modern features
# 3 Neutral “okay but not great” experiences
#
# 🟣 Dashen Bank
# What users like:
#
# 1 Best combination of UI + performance
# 2 Smooth navigation
# 3 High-quality app experience
#
# Pain points:
#
# 1 Some inconsistency in transaction speed
# 2 Occasional bugs
# 3 Requests for UX improvements in specific flows
#
# 🟠 Bank of Abyssinia (BOA)
# What users like:
#
# 1 Simple and user-friendly UI
# 2 Clear, organized screens
#
# Pain points:
#
# 1 Frequent crashes
# 2 Failed or slow transactions
# 3 Login/authentication problems
# 4 Customer support concerns
#
# 6. Final Ranking (Overall App Experience)
#
# After combining sentiment, themes, and review distribution:
#
# 🥇 1. Dashen Bank — Best Overall Experience
#
# -Most positive sentiment
# -Good UI + performance
# -Light but fixable issues
#
# 🥈 2. Commercial Bank of Ethiopia — Most Reliable
#
# -Strong transaction stability
# -High satisfaction
# -Needs modernization
#
# 🥉 3. Bank of Abyssinia — UI Good, Reliability Poor
#
# -Strong design
# -Weak technical performance
# -Support & stability issues
#
# 7. Summary Table (Quick Comparison)
#
# | Criterion               | CBE    | Dashen | BOA     |
# | ----------------------- | ------ | ------ | ------- |
# | Sentiment Score         | ⭐⭐     | ⭐⭐⭐    | ⭐       |
# | Transaction Reliability | ⭐⭐⭐    | ⭐⭐     | ⭐       |
# | UI/UX                   | ⭐⭐     | ⭐⭐⭐    | ⭐⭐⭐     |
# | Negative Reviews        | Lowest | Medium | Highest |
# | Feature Completeness    | ⭐⭐⭐    | ⭐⭐     | ⭐⭐      |
# | Overall Ranking         | #2     | #1     | #3      |
