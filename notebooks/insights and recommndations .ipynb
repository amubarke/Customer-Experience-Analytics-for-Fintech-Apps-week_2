# %% [markdown]
# Task 4: Insights and Recommendations

# %% [markdown]
# 3-Bank Comparison: CBE vs BOA vs Dashen Bank

# %% [markdown]
# 1. Overall Sentiment Comparison

# %% [markdown]
# | Bank                                  | Mean Polarity | Interpretation                                   |
# | ------------------------------------- | ------------- | ------------------------------------------------ |
# | **Commercial Bank of Ethiopia (CBE)** | **0.2296**    | Strong positivity, high customer satisfaction    |
# | **Dashen Bank**                       | **0.2303**    | Slightly higher than CBE — most positive overall |
# | **Bank of Abyssinia (BOA)**           | **0.1027**    | Lowest sentiment; mixed-to-negative experience   |
#
#
# 👉 Dashen Bank takes the #1 spot (slightly higher than CBE)
#
# 👉 BOA is significantly behind both

# %% [markdown]
# 2. Review Volume & Engagement

# %% [markdown]
# | Bank       | Total Reviews | Notes                        |
# | ---------- | ------------- | ---------------------------- |
# | **CBE**    | 296           | Highest, broad customer base |
# | **BOA**    | 286           | High engagement              |
# | **Dashen** | 286           | Same volume as BOA           |
#
# 👉 All banks have comparable review counts — comparison is fair.

# %% [markdown]
# 3. Sentiment Breakdown
#
# CBE
#
# *Positive: 146
#
# *Negative: 27
#
# *Neutral: 123
#
# Excellent positive-to-negative ratio (≈ 5:1)

# %% [markdown]
# Dashen Bank
#
# *Positive: 171
#
# *Negative: 44
#
# *Neutral: 71
#
# High positivity but with more negatives than CBE

# %% [markdown]
# BOA
#
#    *Positive: 121
#
#    *Negative: 63
#
#    *Neutral: 102
#
# Weak sentiment distribution
#
# 👉 Customer happiness ranking → Dashen ≈ CBE >>> BOA

# %% [markdown]
# 4. Thematic Comparison (Pain Points & Strengths)
#
# Shared Themes Across Banks
#
# | Theme                   | Count |
# | ----------------------- | ----- |
# | Transaction Performance | 107   |
# | Feature Requests        | 65    |
# | Customer Support        | 51    |
# | UI/UX                   | 49    |
# | Account Access Issues   | 47    |

# %% [markdown]
# 📌 Bank of Abyssinia (BOA)
#
# Pain Points
#
# *Frequent transaction failures
#
# *Account access issues (login, OTP)
#
# *App crashes / bugs
#
# *Poor customer support responsiveness
#
# Strengths
#
# *Clean, simple UI
#
# *Good account overview features
#
# 👉 Main weakness: stability + support
#
# 📌 Commercial Bank of Ethiopia (CBE)
# Pain Points
#
# *UI feels outdated
#
# *Many users ask for new features
#
# *Strong neutral feedback — “average experience”
#
# Strengths
#
# *Reliable transactions
#
# *High stability
#
# *Smooth core banking functions
#
# 👉 Main strength: dependability
#
# 📌 Dashen Bank
# Pain Points
#
# *Some transaction delays
#
# *Occasional technical issues
#
# *Requests for more convenience features
#
# Strengths
#
# *Highest positive sentiment overall
#
# *Smooth, intuitive interface
#
# *Appreciated for usability & functionality
#
# 👉 Dashen = balanced performance + strong UI

# %% [markdown]
# 5. Key Drivers and Pain Points per Bank

# %% [markdown]
# 🔵 Commercial Bank of Ethiopia (CBE)
#
# Users like:
#
# 1 Reliable transactions
#
# 2 Stable performance
#
# 3 Good daily banking functions
#
# Pain points:
#
# 1 Outdated UI
#
# 2 Requests for modern features
#
# 3 “Okay but not great” experiences
#
# 🟣 Dashen Bank
#
# Users like:
#
# 1 Best mix of UI + performance
#
# 2 Smooth navigation
#
# 3 High-quality app experience
#
# Pain points:
#
# 1 Inconsistent transaction speed
#
# 2 Occasional bugs
#
# 3 UX improvements needed in some flows
#
# 🟠 Bank of Abyssinia (BOA)
#
# Users like:
#
# 1 Simple UI
#
# 2 Clear, organized screens
#
# Pain points:
#
# 1 Frequent crashes
#
# 2 Failed or slow transactions
#
# 3 Login/auth problems
#
# 4 Customer support concerns

# %% [markdown]
# 6. Final Ranking (Overall App Experience)
#
# 🥇 1. Dashen Bank — Best Overall Experience
#
# Most positive sentiment
#
# Strong UI + performance
#
# Issues are minor and fixable
#
# 🥈 2. Commercial Bank of Ethiopia — Most Reliable
#
# High stability
#
# Good satisfaction
#
# Needs UI modernization
#
# 🥉 3. Bank of Abyssinia — Good UI, Poor Reliability
#
# Good design
#
# Weak technical performance
#
# Support + stability issues

# %% [markdown]
# 7. Summary Table (Quick Comparison)

# %% [markdown]
# | Criterion               | CBE    | Dashen | BOA     |
# | ----------------------- | ------ | ------ | ------- |
# | Sentiment Score         | ⭐⭐     | ⭐⭐⭐    | ⭐       |
# | Transaction Reliability | ⭐⭐⭐    | ⭐⭐     | ⭐       |
# | UI/UX                   | ⭐⭐     | ⭐⭐⭐    | ⭐⭐⭐     |
# | Negative Reviews        | Lowest | Medium | Highest |
# | Feature Completeness    | ⭐⭐⭐    | ⭐⭐     | ⭐⭐      |
# | **Overall Ranking**     | **#2** | **#1** | **#3**  |
